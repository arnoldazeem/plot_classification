# %%
import glob
import csv
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
path = "/home/adaboo/Desktop/Masters/sem4/thesis/dataset for plots/activity recognition chest-mounted accelerometer/*.csv"
for fname in glob.glob(path):
     
    with open(fname) as csvfile:
        readCSV = csv.reader(csvfile, delimiter=',')
        for row in readCSV:
            #print(row)
            #print(row[0])
            #print(row[1],row[2])
            x.append(row[1])
            y.append(row[2])
            
x = x[1:6]


y = y[1:10]


x = list(map(int, x))

y = list(map(int, y))

print(y)
# Out:
# [2072, 1957, 1939, 1965, 1959, 1829, 1910, 2045, 2049]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
#objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')

y_pos = np.arange(len(y))

#performance = np.array([10,8,6,4,2,1])
 
plt.bar(y_pos, y, align='center', alpha=0.5)
#plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
#objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')

y_pos = np.arange(len(y))

#performance = np.array([10,8,6,4,2,1])
 
plt.barh(y_pos, y, align='center', alpha=0.5)
#plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()
