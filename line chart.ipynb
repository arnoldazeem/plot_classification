# %%
import glob
import csv
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
path = "/home/adaboo/Desktop/Masters/sem4/thesis/dataset for plots/activity recognition chest-mounted accelerometer/*.csv"
for fname in glob.glob(path):
     
    with open(fname) as csvfile:
        readCSV = csv.reader(csvfile, delimiter=',')
        for row in readCSV:
            #print(row)
            #print(row[0])
            #print(row[1],row[2])
            x.append(row[1])
            y.append(row[2])
            
            
x = x[1:50]
y = y[1:50]


x1= x[40:90]
y1= y[40:90]

# %%
import matplotlib.pyplot as plt



#commenting different types of line charts
plt.plot(x, y, marker='o', linestyle='--', color='r', label='Square')
#plt.plot(x, y)
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 500
#random_x = np.linspace(0, 1, N)
#random_y = np.random.randn(N)

# Create a trace
trace = go.Scatter(
    x = x,
    y = y
)

data = [trace]

py.iplot(data, filename='basic-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~zanzy/4.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 100
random_x = np.linspace(0, 1, N)
random_y0 = np.random.randn(N)+5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N)-5

# Create traces
trace0 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines',
    name = 'lines'
)
trace1 = go.Scatter(
    x = x,
    y = y,
    mode = 'lines+markers',
    name = 'lines+markers'
)
trace2 = go.Scatter(
    x = x,
    y = y,
    mode = 'markers',
    name = 'markers'
)
data = [trace2]

py.iplot(data, filename='line-mode')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~zanzy/6.embed" height="525px" width="100%"></iframe>

# %%
import matplotlib.pyplot as plt

plt.plot(x1, y1)
plt.show()
