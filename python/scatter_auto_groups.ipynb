# %%
import glob
import pandas as pd
import os
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

col_1 = 0
path = "/home/arnold/Documents/thesis/dataset/*.csv"

for fname in glob.glob(path):
    df = (pd.read_csv(StringIO(fname)))
    #graph_name = (os.path.basename(fname))
    df

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import category_scatter

fig = category_scatter(x='x', y='y', label_col=0, 
                       data=df, legend_loc='upper left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-74aa8d4c10ad> in <module>()
#       3
#       4 fig = category_scatter(x='x', y='y', label_col=0,
# ----> 5                        data=df, legend_loc='upper left')
#       6
#       7 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/mlxtend/plotting/scatter.py in category_scatter(x, y, label_col, data, markers, colors, alpha, markersize, legend_loc)
#      53     if isinstance(data, pd.DataFrame):
#      54         for i in (x, y, label_col):
# ---> 55             assert(isinstance(i, str))
#      56         frame = True
#      57         labels = np.unique(data.loc[:, label_col])
#
# AssertionError:

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import category_scatter

fix = category_scatter(x=1, y=2, label_col=0, 
                       data=ary, legend_loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0253c8acadc3> in <module>()
#       3
#       4 fix = category_scatter(x=1, y=2, label_col=0,
# ----> 5                        data=ary, legend_loc='upper left')
#
# NameError: name 'ary' is not defined
